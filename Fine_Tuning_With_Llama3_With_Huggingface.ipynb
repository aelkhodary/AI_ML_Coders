# %% [markdown]
# <a href="https://colab.research.google.com/github/aelkhodary/AI_ML_Coders/blob/main/Fine_Tuning_With_Llama3_With_Huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Outlines the end-to-end pipeline for fine-tuning LLMs, from preparing the base model and data to training and evaluation. It's a practical guide for using libraries like Hugging Face’s transformers and trl.
#
#
# This image provides a clear overview of the key components required to conduct fine-tuning of a Large Language Model (LLM), specifically using frameworks like TRL (Transformers Reinforcement Learning).
#
#
# ✅ Breakdown of the Fine-Tuning Requirements (Left Side)
#
# * Language Model + Tokenizer
#
# You need a pre-trained LLM (like TinyLLaMA-v0) and its corresponding tokenizer.
#
# These form the foundation for text processing and learning.
#
# * Training Dataset
#
# Example: Bitext customer service dataset.
#
# This dataset provides the domain-specific examples the model will learn from.
#
# * Training Arguments
#
# These include hyperparameters like batch size, learning rate, number of epochs, etc.
#
# They control how the model learns.
#
# * Conduct Fine-Tuning
#
# Done using a utility like SFTTrainer (Supervised Fine-Tuning Trainer) from the TRL library.
#
# This wraps everything together to train the model on the dataset with given settings.
#
# * Evaluation Dataset or Benchmark
#
# After training, you need a separate dataset or benchmark to evaluate how well the fine-tuned model performs.
#
#
# # The diagram visualizes the same process:
#
# * Inputs to training
#
# tokenizer, model, training dataset, training arguments, and a fine-tuning class are fed into the training process.
#
# * Training outputs a fine-tuned model
#
# After training, the result is a fine-tuned model tailored to the task or domain.
#
# Model Evaluation
#
# The fine-tuned model is tested using a benchmark or dataset in the evaluation phase to assess its performance.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Excercise
#
# Setting up Llama training arguments
# You are tasked with working with the Llama model used in a customer service chatbot by fine-tuning it on customer service data purpose built for question-answering. To ensure the best performance out of these models, your team will fine-tune a Llama model for this task using the bitext dataset.
#
# You want to do a test run of the training loop to check if the training script works. So, you want to start by setting a small learning rate and limit the training to a handful of steps in your training arguments.
#
# Instructions
# 100 XP
# Import and instantiate the helper class to store your training arguments.
# Set the training argument for learning rate to a value of 2e-3.

# %%
##
